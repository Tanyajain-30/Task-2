# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv(r"C:\Users\Hp\Downloads\01.Data Cleaning and Preprocessing.csv")

# %%
data.head(10)
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
# 5     1-08:00    14.23    15.350      85.518  1171.604      198.538
# 6     1-09:00    13.49    13.700      98.186  1243.688      116.275
# 7    31-06:00    22.65    14.100      91.887  1307.852      288.989
# 8    31-07:00    22.50    14.233      97.249  1346.900      330.325
# 9    31-08:00    24.70    13.850      96.208  1334.892      362.511
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# ...

# %%
data.duplicated().sum()
# Out:
# 23

# %%
data.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
data['UCZAA'] = data['UCZAA'].replace(np.NAN, 0)

# %%
data['BlowFlow']=data['BlowFlow'].mean()

# %%
data['ChipRate']=data['ChipRate'].fillna(method="ffill")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2256\3293375768.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['ChipRate']=data['ChipRate'].fillna(method="ffill")

# %%
data["BF-CMratio"] = data["BF-CMratio"].replace(np.NAN, 0)

# %%
data.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             0
# BF-CMratio           0
# BlowFlow             0
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA                0
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64
